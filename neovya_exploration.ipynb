# %%
import pandas as pd

# %%
data = pd.read_csv("../../Data/Neovya/livraison/split-files/here_data_part_1.csv")

# %%
data[data['LINK-DIR'] == '1002854952T'].head()
# Out:
#       LINK-DIR         DATE-TIME  EPOCH-15MIN  LENGTH  FREEFLOW  SPDLIMIT  \
# 0  1002854952T  2019-01-16 19:00           76     147      72.0      80.0
# 1  1002854952T  2019-01-24 17:45           71     147      72.0      80.0
# 2  1002854952T  2019-04-21 19:00           76     147      72.0      80.0
# 3  1002854952T  2019-05-22 20:15           81     147      72.0      80.0
# 4  1002854952T  2019-06-15 07:15           29     147      72.0      80.0
#
#    COUNT  MEAN  STDDEV  MIN  MAX  CONFIDENCE
# 0      1  65.0     0.0   65   65          10
# 1      2  48.5    16.3   37   60          20
# 2      1  46.0     0.0   46   46          10
# 3      2  28.5     2.1   27   30          30
# 4      1  77.0     0.0   77   77          10

# %%
print(min(data['DATE-TIME']))
max(data['DATE-TIME'])
# Out:
# 2019-01-01 00:00
# '2023-12-31 23:00'

# %%
print(min(data['LENGTH']))
max(data['LENGTH'])
# Out:
# 6
# 372

# %%
import geojson
with open("../../Data/Neovya/livraison/geometries.geojson") as f:
    gj = geojson.load(f)
features = gj['features'][0]

# %%
gj['type'][1]
# Out:
# 'e'

# %%
gj['features']
# Out:
# [{"geometry": {"coordinates": [[-1.48786, 48.09663], [-1.48775, 48.09682], [-1.48772, 48.09694], [-1.48765, 48.09744], [-1.48741, 48.09812], [-1.48711, 48.09862], [-1.48703, 48.09892], [-1.48678, 48.09942], [-1.48672, 48.09958]], "type": "LineString"}, "properties": {"fc": 5, "segmentId": "70980503F"}, "type": "Feature"},
#  {"geometry": {"coordinates": [[-1.48672, 48.09958], [-1.48678, 48.09942], [-1.48703, 48.09892], [-1.48711, 48.09862], [-1.48741, 48.09812], [-1.48765, 48.09744], [-1.48772, 48.09694], [-1.48775, 48.09682], [-1.48786, 48.09663]], "type": "LineString"}, "properties": {"fc": 5, "segmentId": "70980503T"}, "type": "Feature"},
#  {"geometry": {"coordinates": [[-1.48477, 48.09798], [-1.48488, 48.09806], [-1.48515, 48.09832], [-1.48543, 48.09856], [-1.4858, 48.09881], [-1.4863, 48.09922], [-1.48664, 48.09948], [-1.48672, 48.09958]], "type": "LineString"}, "properties": {"fc": 5, "segmentId": "552042150F"}, "type": "Feature"},
# ...
